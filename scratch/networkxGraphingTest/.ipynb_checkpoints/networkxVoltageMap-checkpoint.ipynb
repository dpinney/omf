# %%
import sys, json
sys.path.append('C:/Users/dwp0/Dropbox/OMF/omf')
import feeder

# %%
with open('networkxGraphingTestFeeder.json') as feedFile:
    xFeed = json.load(feedFile)
print xFeed.keys()[1:10]
# Out:
# [u'154720', u'69420', u'16420', u'13020', u'32520', u'120120', u'88620', u'82220', u'57720']

# %%
feeder.latLonNxGraph(feeder.treeToNxGraph(xFeed))

# %%
glmStr = feeder.sortedWrite(xFeed)
glmStr
# Out:
# u'clock {\ntimezone PST+8PDT;\nstoptime \'2000-01-0200:00:00\';\nstarttime \'2000-01-0100:00:00\';\n};\n\n#include "schedules.glm";\n#set minimum_timestep=60;\n#set profiler=1;\n#set relax_naming_rules=1;\nmodule generators;\nmodule tape;\nmodule climate;\nmodule residential {\nimplicit_enduses NONE;\n};\n\nmodule powerflow {\nsolver_method NR;\nNR_iteration_limit 50;\n};\n\nobject climate {\nname Climate;\ninterpolate QUADRATIC;\ntmyfile climate.tmy2;\n};\n\nobject node {\nphases ABCN;\nname BURLINGTON;\nbustype SWING;\nnominal_voltage 7200.0;\n};\n\nobject overhead_line {\nphases ACBN;\nfrom BURLINGTON;\nname 21003;\nto node2101121003;\nlength 20.6237;\nconfiguration 20531line_configuration98301;\n};\n\nobject overhead_line {\nphases ACBN;\nfrom node2101121003;\nname 21011;\nto node6830421011;\nlength 13.0755;\nconfiguration 20531line_configuration98301;\n};\n\nobject overhead_line {\nphases ACBN;\nfrom node6830421011;\nname 68304;\nto node6830568304;\nlength 14.8233;\nconfiguration 20531line_configuration98301;\n};\n\nobject overhead_line {\nphases ACBN;\nfrom node6830421011;\nname 68302;\nto node6830368302;\nlength 10;\nconfiguration 20531line_configuration98301;\n};\n\nobject overhead_line {\nphases ACBN;\nfrom node6830421011;\nname 68300;\nto node6830168300;\nlength 10;\nconfiguration 20531line_configuration98301;\n};\n\nobject overhead_line {\nphases ACBN;\nfrom node6830421011;\nname 68298;\nto node6829968298;\nlength 19.0913;\nconfiguration 20531line_configuration98301;\n};\n\nobject overhead_line {\nphases ACBN;\nfrom node6829968298;\nname 68299;\nto nodeR118268299;\nlength 24.3563;\nconfiguration 20531line_configuration98301;\n};\n\nobject fuse {\nphases ACBN;\nfrom nodeR118268299;\nname R1182;\ncurrent_limit 9999.0 A;\nto node20944R1182;\n};\n\nobject overhead_line {\nphases ACBN;\nfrom node20944R1182;\nname 20944;\nto node2083720944;\nlength 82.2659;\nconfiguration 20531line_configuration98301;\n};\n\nobject overhead_line {\nphases ACBN;\nfrom node2083720944;\nname 20837;\nto node2088120837;\nlength 87.5465;\nconfiguration 20531line_configuration98301;\n};\n\nobject overhead_line {\nphases ACBN;\nfrom node2088120837;\nname 20881;\nto node2044520881;\nlength 281.156;\nconfiguration 20531line_configuration98301;\n};\n\nobject overhead_line {\nphases ACBN;\nfrom node2044520881;\nname 20445;\nto node2054920445;\nlength 465.786;\nconfiguration 20531line_configuration98301;\n};\n\nobject overhead_line {\nphases ACBN;\nfrom node2054920445;\nname 20549;\nto node2036920549;\nlength 212.612;\nconfiguration 20531line_configuration98301;\n};\n\nobject overhead_line {\nphases ACBN;\nfrom node2036920549;\nname 20369;\nto node2050620369;\nlength 302.735;\nconfiguration 20531line_configuration98301;\n};\n\nobject overhead_line {\nphases ACBN;\nfrom node2050620369;\nname 20506;\nto node2036720506;\nlength 178.526;\nconfiguration 20531line_configuration98301;\n};\n\nobject overhead_line {\nphases ACBN;\nfrom node2036720506;\nname 20367;\nto nodeT6246302788020367;\nlength 144.103;\nconfiguration 20531line_configuration98301;\n};\n\nobject transformer {\nphases BS;\nfrom nodeT6246302788020367;\nname T62463027880;\nto node62463027798T62463027880;\nconfiguration T62474206624transformer_configuration90001;\n};\n\nobject triplex_node {\nphases BS;\npower_12 100;\nname 62463027798;\nparent node62463027798T62463027880;\nnominal_voltage 120;\n};\n\nobject overhead_line {\nphases ACBN;\nfrom nodeT6246302788020367;\nname 20286;\nto node2024820286;\nlength 266.66;\nconfiguration 20531line_configuration98301;\n};\n\nobject overhead_line {\nphases ACBN;\nfrom node2024820286;\nname 20248;\nto node2014520248;\nlength 153.517;\nconfiguration 20531line_configuration98301;\n};\n\nobject overhead_line {\nphases ACBN;\nfrom node2014520248;\nname 20145;\nto nodeT6246302460920145;\nlength 357.003;\nconfiguration 20531line_configuration98301;\n};\n\nobject overhead_line {\nphases AN;\nfrom nodeT6246302460920145;\nname 20129;\nto nodeF894420129;\nlength 27. ...
